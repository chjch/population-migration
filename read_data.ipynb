# %%
import pandas as pd

# %%
inflow2021_df = pd.read_csv('data/countyinflow2021.csv')
inflow2021_df.head()
# Out:
#    y2_statefips  y2_countyfips  y1_statefips  y1_countyfips y1_state  \
# 0             1              1            96              0       AL
# 1             1              1            97              0       AL
# 2             1              1            97              1       AL
# 3             1              1            97              3       AL
# 4             1              1            98              0       AL
#
#                                     y1_countyname    n1    n2     agi
# 0   Autauga County Total Migration-US and Foreign  2104  4587  123290
# 1               Autauga County Total Migration-US  2074  4495  120106
# 2       Autauga County Total Migration-Same State  1362  2783   67591
# 3  Autauga County Total Migration-Different State   712  1712   52515
# 4          Autauga County Total Migration-Foreign    30    92    3184
